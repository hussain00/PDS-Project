# %% [markdown]
# <a href="https://colab.research.google.com/github/hussain00/PDS-Project/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

file_1= list(uploaded.keys())[0]
file_2 = list(uploaded.keys())[1]
# Out:
#      <input type="file" id="files-ad0fcfed-1359-434d-af0c-4531cb612135" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad0fcfed-1359-434d-af0c-4531cb612135">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df1 = pd.read_csv(file_1)
df2 = pd.read_csv(file_2)

# %%
mean1 = df1['Marks'].mean()
mean2 = df2['Marks'].mean()

# %%
df1['Marks'] = df1['Marks'].fillna(mean1)
df2['Marks'] = df2['Marks'].fillna(mean2)

# %%
df = pd.merge(df1, df2[['Registration Number', 'Marks']], on='Registration Number')

# %%
df
# Out:
#     Registration Number                        Name    Marks_x    Marks_y
# 0            2017132004       Md Torikul Islam Raju  12.798077   9.904762
# 1            2017132035              Rakibul Hassan   7.000000   7.500000
# 2            2018132012               Mehrab Shadat   7.000000   0.000000
# 3            2018132014      Md Nafis Hasan Ferdous  12.000000   4.500000
# 4            2018132036                    John Doe  14.000000   8.000000
# ..                  ...                         ...        ...        ...
# 59           2019132104           MD. Rakibul Islam  19.000000  15.500000
# 60           2019132105     Md. Khaled Hossain Rafi   7.000000   6.000000
# 61           2019132106              MD SUMON AHMED  18.000000  17.500000
# 62           2019132107             Jibon kumar dev  10.500000  14.500000
# 63           2019132108  MD MAHMUDUL BARI CHOWDHURY   6.500000   8.000000
#
# [64 rows x 4 columns]

# %%
df['Best One'] = df[['Marks_x','Marks_y']].max(axis=1)
df['Average'] = df[['Marks_x','Marks_y']].mean(axis=1)

# %%
df
# Out:
#     Registration Number                        Name    Marks_x    Marks_y  \
# 0            2017132004       Md Torikul Islam Raju  12.798077   9.904762
# 1            2017132035              Rakibul Hassan   7.000000   7.500000
# 2            2018132012               Mehrab Shadat   7.000000   0.000000
# 3            2018132014      Md Nafis Hasan Ferdous  12.000000   4.500000
# 4            2018132036                    John Doe  14.000000   8.000000
# ..                  ...                         ...        ...        ...
# 59           2019132104           MD. Rakibul Islam  19.000000  15.500000
# 60           2019132105     Md. Khaled Hossain Rafi   7.000000   6.000000
# 61           2019132106              MD SUMON AHMED  18.000000  17.500000
# 62           2019132107             Jibon kumar dev  10.500000  14.500000
# 63           2019132108  MD MAHMUDUL BARI CHOWDHURY   6.500000   8.000000
#
#      Best One    Average
# 0   12.798077  11.351419
# 1    7.500000   7.250000
# ...

# %%
df = df.drop(['Marks_x','Marks_y'], axis=1)

# %%
from google.colab import files

uploaded = files.upload()

file_att = list(uploaded.keys())[0]
file_fin = list(uploaded.keys())[1]
# Out:
#      <input type="file" id="files-bba87dae-210e-4d29-ab68-b918a8023ea4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bba87dae-210e-4d29-ab68-b918a8023ea4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
att = pd.read_csv(file_att)
tf = pd.read_csv(file_fin)

# %%
data = df.copy()

# %%
data = pd.merge(data, att[['Registration Number', 'Attendance Marks']], on='Registration Number')

# %%
data
# Out:
#     Registration Number                        Name   Best One    Average  \
# 0            2017132004       Md Torikul Islam Raju  12.798077  11.351419
# 1            2017132035              Rakibul Hassan   7.500000   7.250000
# 2            2018132012               Mehrab Shadat   7.000000   3.500000
# 3            2018132014      Md Nafis Hasan Ferdous  12.000000   8.250000
# 4            2018132036                    John Doe  14.000000  11.000000
# ..                  ...                         ...        ...        ...
# 59           2019132104           MD. Rakibul Islam  19.000000  17.250000
# 60           2019132105     Md. Khaled Hossain Rafi   7.000000   6.500000
# 61           2019132106              MD SUMON AHMED  18.000000  17.750000
# 62           2019132107             Jibon kumar dev  14.500000  12.500000
# 63           2019132108  MD MAHMUDUL BARI CHOWDHURY   8.000000   7.250000
#
#     Attendance Marks
# 0                  6
# 1                  6
# ...

# %%
data = pd.merge(data, tf[['Registration Number', 'Final Exam Marks']], on='Registration Number')

# %%
data
# Out:
#     Registration Number                        Name   Best One    Average  \
# 0            2017132004       Md Torikul Islam Raju  12.798077  11.351419
# 1            2017132035              Rakibul Hassan   7.500000   7.250000
# 2            2018132012               Mehrab Shadat   7.000000   3.500000
# 3            2018132014      Md Nafis Hasan Ferdous  12.000000   8.250000
# 4            2018132036                    John Doe  14.000000  11.000000
# ..                  ...                         ...        ...        ...
# 59           2019132104           MD. Rakibul Islam  19.000000  17.250000
# 60           2019132105     Md. Khaled Hossain Rafi   7.000000   6.500000
# 61           2019132106              MD SUMON AHMED  18.000000  17.750000
# 62           2019132107             Jibon kumar dev  14.500000  12.500000
# 63           2019132108  MD MAHMUDUL BARI CHOWDHURY   8.000000   7.250000
#
#     Attendance Marks  Final Exam Marks
# 0                  6                72
# ...

# %%
data['Final Marks'] = data['Final Exam Marks']*0.7 + data['Average'] + data['Attendance Marks']

# %%
data
# Out:
#     Registration Number                        Name   Best One    Average  \
# 0            2017132004       Md Torikul Islam Raju  12.798077  11.351419
# 1            2017132035              Rakibul Hassan   7.500000   7.250000
# 2            2018132012               Mehrab Shadat   7.000000   3.500000
# 3            2018132014      Md Nafis Hasan Ferdous  12.000000   8.250000
# 4            2018132036                    John Doe  14.000000  11.000000
# ..                  ...                         ...        ...        ...
# 59           2019132104           MD. Rakibul Islam  19.000000  17.250000
# 60           2019132105     Md. Khaled Hossain Rafi   7.000000   6.500000
# 61           2019132106              MD SUMON AHMED  18.000000  17.750000
# 62           2019132107             Jibon kumar dev  14.500000  12.500000
# 63           2019132108  MD MAHMUDUL BARI CHOWDHURY   8.000000   7.250000
#
#     Attendance Marks  Final Exam Marks  Final Marks
# ...

# %%
data.to_csv('final result.csv')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
result_data = pd.read_csv('final result.csv')

# %%
result_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           64 non-null     int64
#  1   Registration Number  64 non-null     int64
#  2   Name                 64 non-null     object
#  3   Best One             64 non-null     float64
#  4   Average              64 non-null     float64
#  5   Attendance Marks     64 non-null     int64
#  6   Final Exam Marks     64 non-null     int64
#  7   Final Marks          64 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 4.1+ KB

# %%
result_data.isnull().sum()
# Out:
# Unnamed: 0             0
# Registration Number    0
# Name                   0
# Best One               0
# Average                0
# Attendance Marks       0
# Final Exam Marks       0
# Final Marks            0
# dtype: int64

# %%
result_data = result_data.iloc[:,1:]

# %%
result_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Registration Number  64 non-null     int64
#  1   Name                 64 non-null     object
#  2   Best One             64 non-null     float64
#  3   Average              64 non-null     float64
#  4   Attendance Marks     64 non-null     int64
#  5   Final Exam Marks     64 non-null     int64
#  6   Final Marks          64 non-null     float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.6+ KB

# %%
#Term Test Average & Total Marks

X1 = result_data.drop(columns=['Registration Number','Name','Best One','Attendance Marks','Final Exam Marks'], axis=1).values

# %%
X1
# Out:
# array([[11.35141941, 67.75141941],
#        [ 7.25      , 72.75      ],
#        [ 3.5       , 67.1       ],
#        [ 8.25      , 75.65      ],
#        [11.        , 90.        ],
#        [10.75      , 70.85      ],
#        [ 6.39903846, 84.69903846],
#        [12.25      , 70.25      ],
#        [12.75      , 71.55      ],
#        [11.5       , 75.5       ],
#        [12.14903846, 84.84903846],
#        [ 6.39903846, 62.09903846],
#        [ 9.25      , 67.05      ],
#        [ 6.64903846, 83.54903846],
#        [ 6.39903846, 68.69903846],
#        [13.25      , 67.45      ],
#        [13.14903846, 86.24903846],
#        [ 6.39903846, 76.59903846],
#        [ 6.39903846, 82.19903846],
#        [10.25      , 80.65      ],
#        [14.25      , 66.45      ],
#        [10.25      , 63.85      ],
#        [ 8.        , 74.5       ],
#        [16.25      , 80.15      ],
#        [17.75      , 83.45      ],
#        [13.75      , 67.25      ],
#        [ 6.39903846, 81.49903846],
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=X1[:,0], y=X1[:, 1])
plt.xlabel('TT Marks')
plt.ylabel('Final Marks')
plt.show()

# %%
wcss=[]
for i in range(1,11):
  kmeans = KMeans(n_clusters=i, init='k-means++', random_state=2)
  kmeans.fit(X1)
  wcss.append(kmeans.inertia_)

plt.figure(figsize=(10,6))
plt.plot(range(1,11), wcss)
plt.title('The Elbow Point Graph')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('wcss')
plt.show()

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=0)
Y1 = kmeans.fit_predict(X1)
Y1
# Out:
# array([1, 4, 4, 4, 0, 1, 2, 1, 1, 1, 0, 3, 1, 2, 4, 1, 0, 4, 2, 2, 1, 3,
#        4, 2, 0, 1, 2, 0, 3, 0, 2, 2, 1, 2, 3, 0, 4, 0, 2, 2, 2, 1, 2, 1,
#        1, 1, 1, 1, 4, 2, 0, 2, 4, 0, 1, 0, 0, 1, 0, 0, 2, 0, 1, 3],
#       dtype=int32)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X1[Y1==0,0], X1[Y1==0,1], s=50, c='red', label='Cluster 1')
plt.scatter(X1[Y1==1,0], X1[Y1==1,1], s=50, c='pink', label='Cluster 2')
plt.scatter(X1[Y1==2,0], X1[Y1==2,1], s=50, c='yellow', label='Cluster 3')
plt.scatter(X1[Y1==3,0], X1[Y1==3,1], s=50, c='green', label='Cluster 4')
plt.scatter(X1[Y1==4,0], X1[Y1==4,1], s=50, c='orange', label='Cluster 5')

plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=200, c='black', label='Centroids')
plt.title('Final Marks vs TT clusters')
plt.xlabel('TT')
plt.ylabel('Final Marks')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=0)
Y2 = kmeans.fit_predict(X1)
Y2
# Out:
# array([1, 1, 1, 2, 0, 1, 2, 1, 1, 2, 0, 1, 1, 2, 1, 1, 0, 2, 2, 2, 1, 1,
#        2, 0, 0, 1, 2, 0, 1, 0, 2, 2, 1, 2, 1, 0, 2, 0, 2, 0, 2, 1, 2, 1,
#        1, 1, 1, 1, 1, 2, 0, 2, 2, 0, 1, 0, 0, 1, 0, 0, 2, 0, 1, 1],
#       dtype=int32)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X1[Y2==0,0], X1[Y2==0,1], s=50, c='red', label='Cluster 1')
plt.scatter(X1[Y2==1,0], X1[Y2==1,1], s=50, c='pink', label='Cluster 2')
plt.scatter(X1[Y2==2,0], X1[Y2==2,1], s=50, c='yellow', label='Cluster 3')

plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=200, c='black', label='Centroids')
plt.title('Final Marks vs TT clusters')
plt.xlabel('TT')
plt.ylabel('Final Marks')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=0)
Y3 = kmeans.fit_predict(X1)
Y3
# Out:
# array([1, 1, 3, 2, 0, 1, 2, 1, 1, 2, 0, 3, 3, 2, 3, 1, 0, 2, 2, 2, 1, 3,
#        2, 0, 0, 1, 2, 0, 3, 0, 2, 2, 1, 2, 3, 0, 2, 0, 2, 0, 2, 1, 2, 1,
#        1, 1, 1, 1, 3, 2, 0, 2, 2, 0, 1, 0, 0, 1, 0, 0, 2, 0, 1, 3],
#       dtype=int32)

# %%
plt.figure(figsize=(10,6))
plt.scatter(X1[Y3==0,0], X1[Y3==0,1], s=50, c='red', label='Cluster 1')
plt.scatter(X1[Y3==1,0], X1[Y3==1,1], s=50, c='pink', label='Cluster 2')
plt.scatter(X1[Y3==2,0], X1[Y3==2,1], s=50, c='yellow', label='Cluster 3')
plt.scatter(X1[Y3==3,0], X1[Y3==3,1], s=50, c='green', label='Cluster 4')

plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=200, c='black', label='Centroids')
plt.title('Final Marks vs TT clusters')
plt.xlabel('TT')
plt.ylabel('Final Marks')
plt.show()
