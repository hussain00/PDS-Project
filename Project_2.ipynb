# %% [markdown]
# <a href="https://colab.research.google.com/github/hussain00/PDS-Project/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

file_1= list(uploaded.keys())[0]
file_2 = list(uploaded.keys())[1]
# Out:
#      <input type="file" id="files-1b3deccd-becf-4b69-8d77-afd4bee8021f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b3deccd-becf-4b69-8d77-afd4bee8021f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df1 = pd.read_csv(file_1)
df2 = pd.read_csv(file_2)

# %%
df = pd.merge(df1, df2[['Registration Number', 'Marks']], on='Registration Number')

# %%
df
# Out:
#     Registration Number                        Name  Marks_x  Marks_y
# 0            2017132004       Md Torikul Islam Raju      NaN      NaN
# 1            2017132035              Rakibul Hassan      7.0      7.5
# 2            2018132012               Mehrab Shadat      7.0      0.0
# 3            2018132014      Md Nafis Hasan Ferdous     12.0      4.5
# 4            2018132036                    John Doe     14.0      8.0
# ..                  ...                         ...      ...      ...
# 59           2019132104           MD. Rakibul Islam     19.0     15.5
# 60           2019132105     Md. Khaled Hossain Rafi      7.0      6.0
# 61           2019132106              MD SUMON AHMED     18.0     17.5
# 62           2019132107             Jibon kumar dev     10.5     14.5
# 63           2019132108  MD MAHMUDUL BARI CHOWDHURY      6.5      8.0
#
# [64 rows x 4 columns]

# %%
df['Best One'] = df[['Marks_x','Marks_y']].max(axis=1)
df['Average'] = df[['Marks_x','Marks_y']].mean(axis=1)

# %%
df
# Out:
#     Registration Number                        Name  Marks_x  Marks_y  \
# 0            2017132004       Md Torikul Islam Raju      NaN      NaN
# 1            2017132035              Rakibul Hassan      7.0      7.5
# 2            2018132012               Mehrab Shadat      7.0      0.0
# 3            2018132014      Md Nafis Hasan Ferdous     12.0      4.5
# 4            2018132036                    John Doe     14.0      8.0
# ..                  ...                         ...      ...      ...
# 59           2019132104           MD. Rakibul Islam     19.0     15.5
# 60           2019132105     Md. Khaled Hossain Rafi      7.0      6.0
# 61           2019132106              MD SUMON AHMED     18.0     17.5
# 62           2019132107             Jibon kumar dev     10.5     14.5
# 63           2019132108  MD MAHMUDUL BARI CHOWDHURY      6.5      8.0
#
#     Best One  Average
# 0        NaN      NaN
# 1        7.5     7.25
# 2        7.0     3.50
# 3       12.0     8.25
# ...

# %%
df = df.drop(['Marks_x','Marks_y'], axis=1)

# %%
from google.colab import files

uploaded = files.upload()

file_att = list(uploaded.keys())[0]
file_fin = list(uploaded.keys())[1]
# Out:
#      <input type="file" id="files-f0584876-955f-4700-b52c-6e5db8f3b567" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0584876-955f-4700-b52c-6e5db8f3b567">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
att = pd.read_csv(file_att)
tf = pd.read_csv(file_fin)

# %%
data = df.copy()

# %%
data = pd.merge(data, att[['Registration Number', 'Attendance Marks']], on='Registration Number')

# %%
data
# Out:
#     Registration Number                        Name  Best One  Average  \
# 0            2017132004       Md Torikul Islam Raju       NaN      NaN
# 1            2017132035              Rakibul Hassan       7.5     7.25
# 2            2018132012               Mehrab Shadat       7.0     3.50
# 3            2018132014      Md Nafis Hasan Ferdous      12.0     8.25
# 4            2018132036                    John Doe      14.0    11.00
# ..                  ...                         ...       ...      ...
# 59           2019132104           MD. Rakibul Islam      19.0    17.25
# 60           2019132105     Md. Khaled Hossain Rafi       7.0     6.50
# 61           2019132106              MD SUMON AHMED      18.0    17.75
# 62           2019132107             Jibon kumar dev      14.5    12.50
# 63           2019132108  MD MAHMUDUL BARI CHOWDHURY       8.0     7.25
#
#     Attendance Marks
# 0                  6
# 1                  6
# 2                  9
# 3                 10
# ...

# %%
data = pd.merge(data, tf[['Registration Number', 'Final Exam Marks']], on='Registration Number')

# %%
data
# Out:
#     Registration Number                        Name  Best One  Average  \
# 0            2017132004       Md Torikul Islam Raju       NaN      NaN
# 1            2017132035              Rakibul Hassan       7.5     7.25
# 2            2018132012               Mehrab Shadat       7.0     3.50
# 3            2018132014      Md Nafis Hasan Ferdous      12.0     8.25
# 4            2018132036                    John Doe      14.0    11.00
# ..                  ...                         ...       ...      ...
# 59           2019132104           MD. Rakibul Islam      19.0    17.25
# 60           2019132105     Md. Khaled Hossain Rafi       7.0     6.50
# 61           2019132106              MD SUMON AHMED      18.0    17.75
# 62           2019132107             Jibon kumar dev      14.5    12.50
# 63           2019132108  MD MAHMUDUL BARI CHOWDHURY       8.0     7.25
#
#     Attendance Marks  Final Exam Marks
# 0                  6                72
# ...

# %%
data['Final Marks'] = data['Final Exam Marks']*0.7 + data['Average'] + data['Attendance Marks']

# %%
data
# Out:
#     Registration Number                        Name  Best One  Average  \
# 0            2017132004       Md Torikul Islam Raju       NaN      NaN
# 1            2017132035              Rakibul Hassan       7.5     7.25
# 2            2018132012               Mehrab Shadat       7.0     3.50
# 3            2018132014      Md Nafis Hasan Ferdous      12.0     8.25
# 4            2018132036                    John Doe      14.0    11.00
# ..                  ...                         ...       ...      ...
# 59           2019132104           MD. Rakibul Islam      19.0    17.25
# 60           2019132105     Md. Khaled Hossain Rafi       7.0     6.50
# 61           2019132106              MD SUMON AHMED      18.0    17.75
# 62           2019132107             Jibon kumar dev      14.5    12.50
# 63           2019132108  MD MAHMUDUL BARI CHOWDHURY       8.0     7.25
#
#     Attendance Marks  Final Exam Marks  Final Marks
# 0                  6                72          NaN
# ...

# %%
data.to_csv('final result.csv')
